# %%
import pandas as pd
df = pd.read_csv('RollingSystemDemand_20220226_0541.csv')
df
# Out:
#                 HDR  ROLLING SYSTEM DEMAND
# VD   20220213000000                25323.0
# VD   20220213000500                25522.0
# VD   20220213001000                25403.0
# VD   20220213001500                25262.0
# VD   20220213002000                25235.0
# ..              ...                    ...
# VD   20220219222000                28408.0
# VD   20220219222500                28157.0
# VD   20220219223000                27853.0
# VD   20220219223500                27631.0
# FTR            2000                    NaN
#
# [2001 rows x 2 columns]

# %%
df.head()
# Out:
#                HDR  ROLLING SYSTEM DEMAND
# VD  20220213000000                25323.0
# VD  20220213000500                25522.0
# VD  20220213001000                25403.0
# VD  20220213001500                25262.0
# VD  20220213002000                25235.0

# %%
df2=df[:-1]
df2
# Out:
#                HDR  ROLLING SYSTEM DEMAND
# VD  20220213000000                25323.0
# VD  20220213000500                25522.0
# VD  20220213001000                25403.0
# VD  20220213001500                25262.0
# VD  20220213002000                25235.0
# ..             ...                    ...
# VD  20220219221500                28655.0
# VD  20220219222000                28408.0
# VD  20220219222500                28157.0
# VD  20220219223000                27853.0
# VD  20220219223500                27631.0
#
# [2000 rows x 2 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, VD to VD
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   HDR                    2000 non-null   int64
#  1   ROLLING SYSTEM DEMAND  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 46.9+ KB

# %%
df2['HDR'] = pd.to_datetime(df2['HDR'],format = '%Y%m%d%H%M%S')
# Out:
# C:\Users\PRANAY~1\AppData\Local\Temp/ipykernel_15144/1928173139.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['HDR'] = pd.to_datetime(df2['HDR'],format = '%Y%m%d%H%M%S')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, VD to VD
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   HDR                    2000 non-null   datetime64[ns]
#  1   ROLLING SYSTEM DEMAND  2000 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 46.9+ KB

# %%
df2
# Out:
#                    HDR  ROLLING SYSTEM DEMAND
# VD 2022-02-13 00:00:00                25323.0
# VD 2022-02-13 00:05:00                25522.0
# VD 2022-02-13 00:10:00                25403.0
# VD 2022-02-13 00:15:00                25262.0
# VD 2022-02-13 00:20:00                25235.0
# ..                 ...                    ...
# VD 2022-02-19 22:15:00                28655.0
# VD 2022-02-19 22:20:00                28408.0
# VD 2022-02-19 22:25:00                28157.0
# VD 2022-02-19 22:30:00                27853.0
# VD 2022-02-19 22:35:00                27631.0
#
# [2000 rows x 2 columns]

# %%
#df2['time'] = df2['HDR'].dt.hour
df2.plot(x='HDR', y='ROLLING SYSTEM DEMAND')
# Out:
# <AxesSubplot:xlabel='HDR'>

# %%
df2["Hour"] = df2["HDR"].dt.hour
df2
# Out:
# C:\Users\PRANAY~1\AppData\Local\Temp/ipykernel_15144/2634249871.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Hour"] = df2["HDR"].dt.hour
#                    HDR  ROLLING SYSTEM DEMAND  Hour
# VD 2022-02-13 00:00:00                25323.0     0
# VD 2022-02-13 00:05:00                25522.0     0
# VD 2022-02-13 00:10:00                25403.0     0
# VD 2022-02-13 00:15:00                25262.0     0
# VD 2022-02-13 00:20:00                25235.0     0
# ..                 ...                    ...   ...
# VD 2022-02-19 22:15:00                28655.0    22
# VD 2022-02-19 22:20:00                28408.0    22
# VD 2022-02-19 22:25:00                28157.0    22
# VD 2022-02-19 22:30:00                27853.0    22
# ...

# %%
g_df2 = df2.groupby('Hour')

# %%
count = 0
for Hour, group in g_df2:
    count = count +1
    print(HDR)
    print(group, "\n")
print(count)
# Out:
# 2022-02-19 22:35:00
#                    HDR  ROLLING SYSTEM DEMAND  Hour
# VD 2022-02-13 00:00:00                25323.0     0
# VD 2022-02-13 00:05:00                25522.0     0
# VD 2022-02-13 00:10:00                25403.0     0
# VD 2022-02-13 00:15:00                25262.0     0
# VD 2022-02-13 00:20:00                25235.0     0
# ..                 ...                    ...   ...
# VD 2022-02-19 00:35:00                25820.0     0
# VD 2022-02-19 00:40:00                26027.0     0
# VD 2022-02-19 00:45:00                26058.0     0
# VD 2022-02-19 00:50:00                26032.0     0
# VD 2022-02-19 00:55:00                25936.0     0
#
# [84 rows x 3 columns]
#
# 2022-02-19 22:35:00
#                    HDR  ROLLING SYSTEM DEMAND  Hour
# VD 2022-02-13 01:00:00                25255.0     1
# VD 2022-02-13 01:05:00                25224.0     1
# VD 2022-02-13 01:10:00                25164.0     1
# VD 2022-02-13 01:15:00                25193.0     1
# ...

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(figsize=(12, 4))
g_df2 = df2.groupby('Hour')["ROLLING SYSTEM DEMAND"].mean().plot(kind='bar', rot=0, ax=axs)
fig.suptitle('Avg of 24 hours showing the average consumption',fontsize=20)
plt.xlabel("Hours",fontsize=16)
plt.ylabel("Rolling System Demand",fontsize=16)
# Out:
# Text(0, 0.5, 'Rolling System Demand')

# %%
df2["day"] = df2["HDR"].dt.day
df2
# Out:
# C:\Users\PRANAY~1\AppData\Local\Temp/ipykernel_15144/3285843305.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["day"] = df2["HDR"].dt.day
#                    HDR  ROLLING SYSTEM DEMAND  Hour  day
# VD 2022-02-13 00:00:00                25323.0     0   13
# VD 2022-02-13 00:05:00                25522.0     0   13
# VD 2022-02-13 00:10:00                25403.0     0   13
# VD 2022-02-13 00:15:00                25262.0     0   13
# VD 2022-02-13 00:20:00                25235.0     0   13
# ..                 ...                    ...   ...  ...
# VD 2022-02-19 22:15:00                28655.0    22   19
# VD 2022-02-19 22:20:00                28408.0    22   19
# VD 2022-02-19 22:25:00                28157.0    22   19
# ...

# %%
g_df2 = df2.groupby(['Hour','day'])

# %%
count=0
for time, group in g_df2:
    print(HDR)
    count=count+1
    print(group, "\n")
print(count)
# Out:
# 2022-02-19 22:35:00
#                    HDR  ROLLING SYSTEM DEMAND  Hour  day
# VD 2022-02-13 00:00:00                25323.0     0   13
# VD 2022-02-13 00:05:00                25522.0     0   13
# VD 2022-02-13 00:10:00                25403.0     0   13
# VD 2022-02-13 00:15:00                25262.0     0   13
# VD 2022-02-13 00:20:00                25235.0     0   13
# VD 2022-02-13 00:25:00                25281.0     0   13
# VD 2022-02-13 00:30:00                25147.0     0   13
# VD 2022-02-13 00:35:00                25251.0     0   13
# VD 2022-02-13 00:40:00                25367.0     0   13
# VD 2022-02-13 00:45:00                25368.0     0   13
# VD 2022-02-13 00:50:00                25329.0     0   13
# VD 2022-02-13 00:55:00                25353.0     0   13
#
# 2022-02-19 22:35:00
#                    HDR  ROLLING SYSTEM DEMAND  Hour  day
# VD 2022-02-14 00:00:00                24810.0     0   14
# VD 2022-02-14 00:05:00                24696.0     0   14
# ...

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(figsize=(24, 7))
g_df2 = df2.groupby(['Hour','day'])["ROLLING SYSTEM DEMAND"].mean().plot(kind='bar', rot=0, ax=axs)
fig.suptitle('7x24 bars showing the average demand',fontsize=30)
plt.xlabel("Hours",fontsize=25)
plt.ylabel("Rolling System Demand",fontsize=25)
# Out:
# Text(0, 0.5, 'Rolling System Demand')

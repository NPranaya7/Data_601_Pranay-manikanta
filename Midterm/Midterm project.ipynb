# %% [markdown]
# # MidTerm Project
#     - Narava Pranay Manikanta -> MT50255
#     - Saketh Reddy M -> WD60571
#     - Date : 12/03/2022
#
# **Applying the EDA techniques on the Baltimore_City_Employee_Salaries dataset.**
#
#
# **Data Source : https://data.baltimorecity.gov/datasets/baltimore-city-employee-salaries/explore**
#
# **Data Description**
# - This data Set is from the time period of 2011 to 2021
# - This data Set contains the annual salary of each officials from Baltimore.
# - We gathered this data from open Baltimore City website

# %% [markdown]
# ### 1.Reading Data.
#
#
# - **Importing Libraries.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# - **Reading Dataset of Baltimore_city Employee_salary.**

# %%
df = pd.read_csv('Baltimore_City_Employee_Salaries.csv')
df
# Out:
#        lastName middleInitial      firstName                       jobClass  \
# 0         Aaron             D         Kareem       UTILITIES INST REPAIR II
# 1         Aaron             R          Lynda        ELECTION JUDGES REGULAR
# 2         Aaron             G       Patricia  FACILITIES/OFFICE SERVICES II
# 3        Abadir             O           Adam          OPERATIONS OFFICER II
# 4         Abaku             O  Aigbolosimuan             POLICE OFFICER EID
# ...         ...           ...            ...                            ...
# 154182      NaN             9            BPD                            BPD
# 154183      NaN             0            BPD                            BPD
# 154184      NaN             1            BPD                            BPD
# 154185      NaN             2            BPD                            BPD
# 154186      NaN             3            BPD                            BPD
#
# ...

# %% [markdown]
# - **Shape of the Data Frame**

# %%
df.shape
# Out:
# (154187, 11)

# %% [markdown]
# - **Details of each columns in DataFrame**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154187 entries, 0 to 154186
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   lastName       153777 non-null  object
#  1   middleInitial  121195 non-null  object
#  2   firstName      154187 non-null  object
#  3   jobClass       154003 non-null  object
#  4   agencyName     154187 non-null  object
#  5   agencyID       154187 non-null  object
#  6   annualSalary   154187 non-null  float64
#  7   grossPay       154187 non-null  float64
#  8   hireDate       154185 non-null  object
#  9   fiscalYear     154187 non-null  object
#  10  ObjectId       154187 non-null  int64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 12.9+ MB

# %% [markdown]
# ## **DATA CLEANNING**

# %% [markdown]
# - **Looking for NULL values in columns and replacing them with appropriate Values**

# %%
df['lastName'].isna().values.any()
# Out:
# True

# %% [markdown]
# - **Locating null values in lastName column**

# %%
df.loc[df.lastName.isna()]
# Out:
#        lastName middleInitial firstName jobClass         agencyName agencyID  \
# 31063       NaN             1       BPD    BPD 1              BPD 1      BPD
# 31067       NaN             0       BPD   BPD 10              BPD 1      BPD
# 31069       NaN             1       BPD   BPD 11              BPD 1      BPD
# 31075       NaN             2       BPD   BPD 12              BPD 1      BPD
# 31080       NaN             3       BPD   BPD 13              BPD 1      BPD
# ...         ...           ...       ...      ...                ...      ...
# 154182      NaN             9       BPD      BPD  Police Department      A99
# 154183      NaN             0       BPD      BPD  Police Department      A99
# 154184      NaN             1       BPD      BPD  Police Department      A99
# 154185      NaN             2       BPD      BPD  Police Department      A99
# 154186      NaN             3       BPD      BPD  Police Department      A99
#
# ...

# %% [markdown]
# - **Null values in LastName Was replaced by UNK (unknown)**

# %%
df.lastName.fillna('UNK', inplace=True)

# %%
df.lastName
# Out:
# 0          Aaron
# 1          Aaron
# 2          Aaron
# 3         Abadir
# 4          Abaku
#            ...
# 154182       UNK
# 154183       UNK
# 154184       UNK
# 154185       UNK
# 154186       UNK
# Name: lastName, Length: 154187, dtype: object

# %%
df['lastName'].isna().values.any()
# Out:
# False

# %%
df['middleInitial'].isna().values.any()
# Out:
# True

# %%
df.loc[df.middleInitial.isna()]
# Out:
#            lastName middleInitial  firstName                       jobClass  \
# 5          Abbeduto           NaN       Mack     ASSISTANT STATE'S ATTORNEY
# 6       Abbott-Cole           NaN   Michelle         OPERATIONS OFFICER III
# 9          Abdrabou           NaN      Fouad                 POLICE OFFICER
# 10            Abdul           NaN      Jalil                     ENGINEER I
# 13      Abdul-Hamid           NaN       Umar     OPERATIONS TECH APPRENTICE
# ...             ...           ...        ...                            ...
# 154097          Zhu           NaN       Qing  BUDGET/MANAGEMENT ANALYST III
# 154104     Zillmann           NaN  Josephine                 DEPUTY SHERIFF
# 154107       Zohios           NaN       John                 POLICE OFFICER
# 154110       Zucker           NaN    Heather                  SALES MANAGER
# 154112        Zurek           NaN  Elizabeth             NURSE PRACTITIONER
#
# ...

# %% [markdown]
# - **Null values in Middle intial Was replaced by first letter in first name**

# %%
midint = df['firstName'].astype(str).str[0]

# %%
df.middleInitial.fillna(midint, inplace=True)

# %%
df['middleInitial'].isna().values.any()
# Out:
# False

# %%
df['firstName'].isna().values.any()
# Out:
# False

# %%
df['jobClass'].isna().values.any()
# Out:
# True

# %%
df.loc[df.jobClass.isna()]
# Out:
#              lastName middleInitial firstName jobClass  \
# 152             Allen             C   Charles      NaN
# 160             Allen             F  Franklin      NaN
# 281               Aka             T    Tongwa      NaN
# 377    Alvarez-Gibson             A      Aiko      NaN
# 471            Barnes             S    Tonyae      NaN
# ...               ...           ...       ...      ...
# 13844       Winiarski             D     Dylan      NaN
# 13894            Wood             A     Andre      NaN
# 13899            Winn             J   Jessica      NaN
# 14103           Young             K    Khalia      NaN
# 14302      Wright III             E     Lewis      NaN
#
#                                         agencyName agencyID  annualSalary  \
# 152                              Police Department      A99           0.0
# 160                               General Services      A85           0.0
# 281                                 Mayor's Office      A01          20.0
# ...

# %% [markdown]
# - **Null values in Jobclass Was replaced by agencyName**

# %%
df.jobClass.fillna(df.agencyName, inplace=True)

# %%
df['jobClass'].isna().values.any()
# Out:
# False

# %%
df['agencyID'].isna().values.any()
# Out:
# False

# %%
df['agencyName'].isna().values.any()
# Out:
# False

# %%
df['annualSalary'].isna().values.any()
# Out:
# False

# %%
df['grossPay'].isna().values.any()
# Out:
# False

# %%
df['fiscalYear'].isna().values.any()
# Out:
# False

# %%
df['ObjectId'].isna().values.any()
# Out:
# False

# %% [markdown]
# - **No of Government Agencies that present in Baltimore**

# %%
g_df = df.groupby(['agencyID','agencyName'])

# %%
c = 0
for i, group in g_df:
    print(c,i)
    #print(group['annualSalary'])
    c = c + 1
# Out:
# 0 ('A01', "Mayor's Office")
# 1 ('A02', 'City Council')
# 2 ('A03', "Mayor's Office of Employment Development")
# 3 ('A04', 'Recreation & Parks - Recreation')
# 4 ('A06', 'Housing & Community Development')
# 5 ('A08', "Mayor's Office of Homeless Services")
# 6 ('A09', 'Liquor License Board')
# 7 ('A10', 'MOCFS')
# 8 ('A11', 'Office of the Inspector General')
# 9 ('A12', 'Finance - Accounting & Payroll')
# 10 ('A14', 'Finance - Collections')
# 11 ('A15', 'Comptroller - Real Estate')
# 12 ('A16', 'Comptroller')
# 13 ('A17', 'Finance - Purchasing')
# 14 ('A18', 'Finance - Treasury')
# 15 ('A19', 'Planning')
# 16 ('A23', 'Finance - Administration & Budgets')
# 17 ('A24', 'Comptroller - Audits')
# 18 ('A26', "Labor Commissioner's Office")
# 19 ('A28', 'Wage Commissioner')
# 20 ('A29', "State's Attorney's Office")
# 21 ('A30', 'Law Department')
# 22 ('A31', 'Courts - Circuit Court')
# 23 ('A32', 'Finance - Risk Management')
# 24 ('A33', 'Legislative Reference')
# 25 ('A35', 'Elections')
# ...

# %% [markdown]
# - **No of People working in each department**

# %%
NPD = pd.value_counts(df.agencyName)

# %%
NPD
# Out:
# Police Department                     34707
# Fire Department                       18374
# Public Works - Water & Waste Water    16353
# Health Department                      9640
# Transportation - Highways              7007
#                                       ...
# War Memorial Commission                   8
# Wage Commissioner                         3
# HLTH-Emergency Medical Team               3
# FIN-RSP Admin (001)                       2
# Una 01 (001)                              1
# Name: agencyName, Length: 71, dtype: int64

# %%
summ = cdf.groupby('agencyName')["annualSalary"].sum()

# %%
summ.idxmax()
# Out:
# <bound method Series.idxmax of agencyName
# BCIT 311 Call Center                                    2606985.00
# Baltimore City Office of Information and Technology    98481842.30
# Cable & Communications                                  3194439.00
# City Council                                           53468973.96
# Community Relations (inactive)                          1242528.00
#                                                           ...
# Transportation Highways                                41415574.00
# W07 - OED - Youth Works                                 3003680.00
# Wage Commissioner                                        172921.00
# War Memorial Commission                                  331690.00
# Youth Cust                                              5482464.00
# Name: annualSalary, Length: 67, dtype: float64>

# %%
df["annualSalary"].max()
# Out:
# 276375.0

# %%
df["annualSalary"].min()
# Out:
# 0.0

# %% [markdown]
# - **Removing a row which having the Annual Salary 0**

# %%
df.drop(df[df['annualSalary'] <100].index, inplace = True)

# %%
df["annualSalary"].min()
# Out:
# 377.0

# %% [markdown]
# - **No of people getting the Same Salary**

# %%
df["annualSalary"].value_counts()
# Out:
# 20800.0     1447
# 24960.0     1212
# 22880.0     1030
# 15080.0      847
# 21008.0      664
#             ...
# 47467.0        1
# 74891.0        1
# 42125.0        1
# 178000.0       1
# 48006.0        1
# Name: annualSalary, Length: 13297, dtype: int64

# %%
df
# Out:
#         lastName middleInitial      firstName                       jobClass  \
# 0          Aaron             D         Kareem       UTILITIES INST REPAIR II
# 2          Aaron             G       Patricia  FACILITIES/OFFICE SERVICES II
# 3         Abadir             O           Adam          OPERATIONS OFFICER II
# 4          Abaku             O  Aigbolosimuan             POLICE OFFICER EID
# 5       Abbeduto             M           Mack     ASSISTANT STATE'S ATTORNEY
# ...          ...           ...            ...                            ...
# 154182       UNK             9            BPD                            BPD
# 154183       UNK             0            BPD                            BPD
# 154184       UNK             1            BPD                            BPD
# 154185       UNK             2            BPD                            BPD
# 154186       UNK             3            BPD                            BPD
#
# ...

# %%
cg_df = df.groupby(['agencyID','agencyName'])

# %%
c = 0
for i, group in cg_df:
    print(c,i)
    #print(group['annualSalary'])
    c = c + 1
# Out:
# 0 ('A01', "Mayor's Office")
# 1 ('A02', 'City Council')
# 2 ('A03', "Mayor's Office of Employment Development")
# 3 ('A04', 'Recreation & Parks - Recreation')
# 4 ('A06', 'Housing & Community Development')
# 5 ('A08', "Mayor's Office of Homeless Services")
# 6 ('A09', 'Liquor License Board')
# 7 ('A10', 'MOCFS')
# 8 ('A11', 'Office of the Inspector General')
# 9 ('A12', 'Finance - Accounting & Payroll')
# 10 ('A14', 'Finance - Collections')
# 11 ('A15', 'Comptroller - Real Estate')
# 12 ('A16', 'Comptroller')
# 13 ('A17', 'Finance - Purchasing')
# 14 ('A18', 'Finance - Treasury')
# 15 ('A19', 'Planning')
# 16 ('A23', 'Finance - Administration & Budgets')
# 17 ('A24', 'Comptroller - Audits')
# 18 ('A26', "Labor Commissioner's Office")
# 19 ('A28', 'Wage Commissioner')
# 20 ('A29', "State's Attorney's Office")
# 21 ('A30', 'Law Department')
# 22 ('A31', 'Courts - Circuit Court')
# 23 ('A32', 'Finance - Risk Management')
# 24 ('A33', 'Legislative Reference')
# 25 ('A35', 'Elections')
# ...

# %% [markdown]
# - **Replacing the agency name with their common agency**

# %%
cdf = df.replace({'agencyID': {'A9': 'A99', 'BPD': 'A99'}})
cdf = cdf.replace({'agencyName': {'BPD 1': 'Police Department'}})

# %%
cg_df2 = cdf.groupby(['agencyID','agencyName'])

# %%
c = 0
for i, group in cg_df2:
    print(c,i)
    #print(group['annualSalary'])
    c = c + 1
# Out:
# 0 ('A01', "Mayor's Office")
# 1 ('A02', 'City Council')
# 2 ('A03', "Mayor's Office of Employment Development")
# 3 ('A04', 'Recreation & Parks - Recreation')
# 4 ('A06', 'Housing & Community Development')
# 5 ('A08', "Mayor's Office of Homeless Services")
# 6 ('A09', 'Liquor License Board')
# 7 ('A10', 'MOCFS')
# 8 ('A11', 'Office of the Inspector General')
# 9 ('A12', 'Finance - Accounting & Payroll')
# 10 ('A14', 'Finance - Collections')
# 11 ('A15', 'Comptroller - Real Estate')
# 12 ('A16', 'Comptroller')
# 13 ('A17', 'Finance - Purchasing')
# 14 ('A18', 'Finance - Treasury')
# 15 ('A19', 'Planning')
# 16 ('A23', 'Finance - Administration & Budgets')
# 17 ('A24', 'Comptroller - Audits')
# 18 ('A26', "Labor Commissioner's Office")
# 19 ('A28', 'Wage Commissioner')
# 20 ('A29', "State's Attorney's Office")
# 21 ('A30', 'Law Department')
# 22 ('A31', 'Courts - Circuit Court')
# 23 ('A32', 'Finance - Risk Management')
# 24 ('A33', 'Legislative Reference')
# 25 ('A35', 'Elections')
# ...

# %% [markdown]
# - **No of people in each department after cleanning**

# %%
CNPD= pd.value_counts(cdf.agencyName)
CNPD
# Out:
# Police Department                     34674
# Fire Department                       18370
# Public Works - Water & Waste Water    16349
# Health Department                      9558
# Transportation - Highways              7006
#                                       ...
# Office of the Inspector General          15
# War Memorial Commission                   8
# Wage Commissioner                         3
# HLTH-Emergency Medical Team               3
# FIN-RSP Admin (001)                       2
# Name: agencyName, Length: 67, dtype: int64

# %%
cdf
# Out:
#         lastName middleInitial      firstName                       jobClass  \
# 0          Aaron             D         Kareem       UTILITIES INST REPAIR II
# 2          Aaron             G       Patricia  FACILITIES/OFFICE SERVICES II
# 3         Abadir             O           Adam          OPERATIONS OFFICER II
# 4          Abaku             O  Aigbolosimuan             POLICE OFFICER EID
# 5       Abbeduto             M           Mack     ASSISTANT STATE'S ATTORNEY
# ...          ...           ...            ...                            ...
# 154182       UNK             9            BPD                            BPD
# 154183       UNK             0            BPD                            BPD
# 154184       UNK             1            BPD                            BPD
# 154185       UNK             2            BPD                            BPD
# 154186       UNK             3            BPD                            BPD
#
# ...

# %% [markdown]
# - **Highest Salary in entire Baltimore**

# %%
cdf.loc[cdf.annualSalary.idxmax()]
# Out:
# lastName                    Harrison
# middleInitial                      S
# firstName                    Michael
# jobClass         POLICE COMMISSIONER
# agencyName         Police Department
# agencyID                         A99
# annualSalary                276375.0
# grossPay                   273270.82
# hireDate                  2019-02-11
# fiscalYear                    FY2021
# ObjectId                        5570
# Name: 5569, dtype: object

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152055 entries, 0 to 154186
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   lastName       152055 non-null  object
#  1   middleInitial  152055 non-null  object
#  2   firstName      152055 non-null  object
#  3   jobClass       152055 non-null  object
#  4   agencyName     152055 non-null  object
#  5   agencyID       152055 non-null  object
#  6   annualSalary   152055 non-null  float64
#  7   grossPay       152055 non-null  float64
#  8   hireDate       152054 non-null  object
#  9   fiscalYear     152055 non-null  object
#  10  ObjectId       152055 non-null  int64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 18.0+ MB

# %% [markdown]
# ## **Visulization**

# %%
fig, axs = plt.subplots(figsize=(24, 7))
g_df2 =  pd.value_counts(cdf.agencyName).plot(kind='bar', rot=90, ax=axs)
fig.suptitle('No of people in each department',fontsize=25)
plt.xlabel("Departments",fontsize=25)
plt.ylabel("People Count",fontsize=25)
# Out:
# Text(0, 0.5, 'People Count')

# %%
fig, axs = plt.subplots(figsize=(24, 7))
g_df2 = cdf.groupby('agencyName')["annualSalary"].mean().plot(kind='bar', rot=90, ax=axs)
fig.suptitle('Avg Annual Salary of each department',fontsize=25)
plt.xlabel("Department",fontsize=25)
plt.ylabel("Salary",fontsize=25)
# Out:
# Text(0, 0.5, 'Salary')

# %%
fig, axs = plt.subplots(figsize=(24, 7))
g_df2 = cdf.groupby(['agencyName','agencyID'])["grossPay"].mean().plot(kind='bar', rot=90, ax=axs)
fig.suptitle('Avg Annual Grosspay of each department',fontsize=30)
plt.xlabel("Department",fontsize=25)
plt.ylabel("Grosspay",fontsize=25)
# Out:
# Text(0, 0.5, 'Grosspay')

# %%
fig, axs = plt.subplots(figsize=(24, 7))
g_df2 = cdf.groupby('agencyName')["annualSalary"].plot(kind='hist', rot=90, ax=axs)
fig.suptitle('Avg Annual Salary of each department',fontsize=25)
plt.xlabel("Department",fontsize=25)
plt.ylabel("Salary",fontsize=25)
# Out:
# Text(0, 0.5, 'Salary')

# %%
plot = sns.displot(data = cdf, x= 'annualSalary', kind = 'kde', height= 10, aspect = 2).set(title='kernel density estimate of Annual Salary')
sns.set(font_scale = 2)
plt.xlabel("AnnualSalary")
plt.ylabel("Density")
# Out:
# Text(0.42499999999999716, 0.5, 'Density')

# %%
plot = sns.displot(data = cdf, x= 'annualSalary', kind = 'ecdf', height= 10, aspect = 2).set(title = 'Empirical distribution function')
#Empirical distribution function
sns.set(font_scale = 2)
plt.xlabel("AnnualSalary")
plt.ylabel("Density")
# Out:
# Text(21.92, 0.5, 'Density')

# %%
plot = sns.displot(data = cdf, x= 'annualSalary', kind = 'hist', height= 10, aspect = 2).set(title = 'Histogram of Annual Salary')
sns.set(font_scale = 2)
plt.xlabel("AnnualSalary")
plt.ylabel("Count")
# Out:
# Text(3.5450000000000017, 0.5, 'Count')

# %%
plot= sns.displot(data=cdf, kind="kde", x="annualSalary", hue = 'agencyName',height= 10, aspect=2, alpha=1).set(title = 'kernel density estimate of Annual Salary by each department')
sns.set(font_scale = 2)
plt.xlabel("AnnualSalary")
plt.ylabel("Density")
plot.ax.grid()
# Out:
# C:\Users\Pranaya Manikanta N\anaconda3\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
plot= sns.displot(data=cdf, kind="kde", x="grossPay", hue = 'agencyName',height= 10, aspect=2, alpha=1).set(title = 'kernel density estimate of GrossPay by each department')
sns.set(font_scale = 2)
plt.xlabel("AnnualSalary")
plt.ylabel("Density")
plot.ax.grid()

# %%
g_df = df.groupby(['fiscalYear'])

# %%
c = 0
for i, group in g_df:
    print(c,i)
    print(group)
    #print(group['annualSalary'])
    c = c + 1
# Out:
# 0 FY2011
#          lastName middleInitial  firstName                        jobClass  \
# 139600    Addison             D   Rosalind               OFFICE SUPERVISOR
# 139601    Addison             W    Wendell  UTILITIES INSTALLER REPAIR III
# 139602  Ademiluyi             B  Burnadeen        HOUSING INSPECTOR SENIOR
# 139603     Adeojo             A      Haviz            PROGRAM ASSISTANT II
# 139604    Adetola             A    Adewale                    ACCOUNTANT I
# ...           ...           ...        ...                             ...
# 154182        UNK             9        BPD                             BPD
# 154183        UNK             0        BPD                             BPD
# 154184        UNK             1        BPD                             BPD
# 154185        UNK             2        BPD                             BPD
# 154186        UNK             3        BPD                             BPD
#
# ...

# %%
fig, axs = plt.subplots(figsize=(24, 7))
g_df2 = cdf.groupby(['fiscalYear'])["annualSalary"].mean().plot(kind='bar', rot=90, ax=axs)
fig.suptitle('Avg Annual annualSalary of each department',fontsize=30)
plt.xlabel("Department",fontsize=25)
plt.ylabel("Grosspay",fontsize=25)
# Out:
# Text(0, 0.5, 'Grosspay')

# %% [markdown]
# ## Conclusion
# - **From the Cleaned Data we learned that in Baltimore there are 67 Goverment Agencies**
# - **Among all These Agencies BPD Baltimore police department are the most densed with the count 34674**
# - **Followed by Fire Department & Health Department**
# - **police department Holds the Highest salary in Baltimore**

# %% [markdown]
# ## What We Learned
# - **we Learned the Mergeing of Data Frames**
# - **Learned How to Deal with the Null values**
# - **Learned how to deal with in conclusive Data**
# - **Learned about seaBorn and how to plot the graphs using SeaBorn**
# - **in Seaborns We learned about three different graphs like kde(kernel density estimate),ECDF(Empirical distribution function)**
# - **And we also learned about EDA**
